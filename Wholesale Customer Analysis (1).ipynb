# %% [markdown]
# Wholesale Customer Analysis

# %% [markdown]
# A wholesale distributor operating in different regions of Portugal has information on annual spending of several items in their stores across different regions and channels. The data (Wholesale Customer.csv) consists of 440 large retailers’ annual spending on 6 different varieties of products in 3 different regions (Lisbon, Oporto, Other) and across different sales channel (Hotel, Retail).

# %% [markdown]
# Basic Python Package Load

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# Load Dataset

# %%
mydata=pd.read_csv('/content/drive/MyDrive/Smita/Google Drive/Great Learning/Module _Projects_GL/Statistics/Wholesale Customer.csv')

# %% [markdown]
# Exploratory Data Analysis

# %%
mydata.head()
# Out:
#    Buyer/Spender Channel Region  ...  Frozen  Detergents_Paper  Delicatessen
# 0              1  Retail  Other  ...     214              2674          1338
# 1              2  Retail  Other  ...    1762              3293          1776
# 2              3  Retail  Other  ...    2405              3516          7844
# 3              4   Hotel  Other  ...    6404               507          1788
# 4              5  Retail  Other  ...    3915              1777          5185
#
# [5 rows x 9 columns]

# %%
mydata.tail()
# Out:
#      Buyer/Spender Channel Region  ...  Frozen  Detergents_Paper  Delicatessen
# 435            436   Hotel  Other  ...   13135               182          2204
# 436            437   Hotel  Other  ...    4510                93          2346
# 437            438  Retail  Other  ...     437             14841          1867
# 438            439   Hotel  Other  ...    1038               168          2125
# 439            440   Hotel  Other  ...      65               477            52
#
# [5 rows x 9 columns]

# %% [markdown]
# Lets check the dtypes of variables in dataframe

# %%
mydata.dtypes
# Out:
# Buyer/Spender        int64
# Channel             object
# Region              object
# Fresh                int64
# Milk                 int64
# Grocery              int64
# Frozen               int64
# Detergents_Paper     int64
# Delicatessen         int64
# dtype: object

# %% [markdown]
# From the above ressults,we can see that except "Channel" and "Region" all others are of integer data types.

# %% [markdown]
# Removal of unwanted variable "Buyer/Spender" which is unique number and useless for the analysis .

# %%
mydata.drop('Buyer/Spender',axis=1,inplace=True)

# %% [markdown]
# Again check the data set after the removal of "Buyer/Spender" from the dataset .

# %%
mydata.head()
# Out:
#   Channel Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# 0  Retail  Other  12669  9656     7561     214              2674          1338
# 1  Retail  Other   7057  9810     9568    1762              3293          1776
# 2  Retail  Other   6353  8808     7684    2405              3516          7844
# 3   Hotel  Other  13265  1196     4221    6404               507          1788
# 4  Retail  Other  22615  5410     7198    3915              1777          5185

# %% [markdown]
# Now ,Lets perform some measures of Discriptive Statistics

# %% [markdown]
# Lets check the number of rows(observations) and number of columns(variables) in dataset.

# %%
mydata.shape
# Out:
# (440, 8)

# %% [markdown]
# There are total 440 rows and 8 columns in data set.

# %% [markdown]
# Let us check if any values in data set is null using info function that gives complete information about the data set.

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    object
#  1   Region            440 non-null    object
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicatessen      440 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 27.6+ KB

# %% [markdown]
# The data has 440 observations and 8 columns .The count of 6 integer variables and 2 object variables.There are no missing value in data .

# %%
mydata.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicatessen        0
# dtype: int64

# %% [markdown]
# From the above ressults,its evident that there is no missing value in data set.

# %%
mydata.describe(include='all')
# Out:
#        Channel Region  ...  Detergents_Paper  Delicatessen
# count      440    440  ...        440.000000    440.000000
# unique       2      3  ...               NaN           NaN
# top      Hotel  Other  ...               NaN           NaN
# freq       298    316  ...               NaN           NaN
# mean       NaN    NaN  ...       2881.493182   1524.870455
# std        NaN    NaN  ...       4767.854448   2820.105937
# min        NaN    NaN  ...          3.000000      3.000000
# 25%        NaN    NaN  ...        256.750000    408.250000
# 50%        NaN    NaN  ...        816.500000    965.500000
# 75%        NaN    NaN  ...       3922.000000   1820.250000
# max        NaN    NaN  ...      40827.000000  47943.000000
#
# [11 rows x 8 columns]

# %% [markdown]
# Let us check the mean and other measures of dispersions using summary statistics.

# %% [markdown]
# From the above descriptive statistics,the average spending on Fresh is 12000,mild is 5796 ,Grocery is 7951,Frozen is 3071 ,Detergent is 2881 and Delicatessen is 1524.
# From the above results ,we can say that highest amount of spending is on Fresh.

# %% [markdown]
# Since the mean and median of all variables are not same and there is a huge difference,we can say that the variables are highly skewed .

# %%
mydata.median()
# Out:
# Fresh               8504.0
# Milk                3627.0
# Grocery             4755.5
# Frozen              1526.0
# Detergents_Paper     816.5
# Delicatessen         965.5
# dtype: float64

# %%
mydata.mean()
# Out:
# Fresh               12000.297727
# Milk                 5796.265909
# Grocery              7951.277273
# Frozen               3071.931818
# Detergents_Paper     2881.493182
# Delicatessen         1524.870455
# dtype: float64

# %% [markdown]
# Mode Calculations:
# The "mode" is the value that occurs most often.

# %%
mydata['Region'].mode()
# Out:
# 0    Other
# dtype: object

# %% [markdown]
# The most often occur (Mode) value of Region is other.

# %%
mydata['Channel'].mode()
# Out:
# 0    Hotel
# dtype: object

# %% [markdown]
# The most often occur value(Mode) of Channel is Hotel

# %% [markdown]
# We will check if the multi modal value occurs in data set or not using below loop .Herein we take all variables except region and channel and check the value counts of each variables to see if there any multimodal values .

# %%
for i in mydata.columns[2:8]:
  print (mydata[i].value_counts(ascending=False).head(5))
# Out:
# 9670     2
# 3        2
# 8040     2
# 514      2
# 18044    2
# Name: Fresh, dtype: int64
# 1897    2
# 5139    2
# 659     2
# 829     2
# 944     2
# Name: Milk, dtype: int64
# 1664    2
# 2405    2
# 1493    2
# 1563    2
# 3600    2
# Name: Grocery, dtype: int64
# 744     2
# 779     2
# 1619    2
# 364     2
# 848     2
# Name: Frozen, dtype: int64
# 227    2
# 311    2
# 118    2
# 811    2
# 788    2
# Name: Detergents_Paper, dtype: int64
# 834     4
# 3       4
# 548     3
# 1215    3
# 395     3
# Name: Delicatessen, dtype: int64

# %% [markdown]
# Modal value for Delicatessen is 834 that appears 4 times ,3 mode appears 4 times .Thus we can says for each variables there are lot of modal values and likewise for other variables.

# %% [markdown]
# Now lets check the value count sof Region and Channel variables

# %%
mydata['Region'].value_counts()
# Out:
# Other     316
# Lisbon     77
# Oporto     47
# Name: Region, dtype: int64

# %% [markdown]
# There are 47 observations of Oporto ,77 observations of Lisbon and 316 observations of other regions.

# %%
mydata['Channel'].value_counts()
# Out:
# Hotel     298
# Retail    142
# Name: Channel, dtype: int64

# %% [markdown]
# There are 142 observations for Retail and 298 observations for Hotel.

# %% [markdown]
# Now will creat a new coloumn of Total  of spendings by 6 different varieties.

# %%
mydata['Total']=mydata.sum(axis=1)

# %%
mydata.head()
# Out:
#   Channel Region  Fresh  Milk  ...  Frozen  Detergents_Paper  Delicatessen  Total
# 0  Retail  Other  12669  9656  ...     214              2674          1338  34112
# 1  Retail  Other   7057  9810  ...    1762              3293          1776  33266
# 2  Retail  Other   6353  8808  ...    2405              3516          7844  36610
# 3   Hotel  Other  13265  1196  ...    6404               507          1788  27381
# 4  Retail  Other  22615  5410  ...    3915              1777          5185  46100
#
# [5 rows x 9 columns]

# %% [markdown]
# Here Total is summations of First row like 34112 is sum of 12669,9656,7561,214,2674 and 1338.

# %% [markdown]
# Creat a bar plot to check the spendings as per Region

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.figure(figsize=(10,8))
regionaggregated=pd.DataFrame(mydata.groupby(["Region"],sort=True)["Total"].sum()).reset_index()
a=sns.barplot(x=regionaggregated["Region"], y=regionaggregated['Total'],data=regionaggregated)
a.set_title("Spending Barplot Region wise",fontsize=15)
plt.show()

# %%
# We have calculated the tota spending for each of the regions.

# %%
regionaggregated.head()
# Out:
#    Region     Total
# 0  Lisbon   2386813
# 1  Oporto   1555088
# 2   Other  10677599

# %% [markdown]
# From the above barplot ,it is seen other region is spending the highest and Oporto is spending the least .

# %% [markdown]
# Creat a bar plot to check the spendings as per Channels

# %%
plt.figure(figsize=(10,8))
channelaggregated=pd.DataFrame(mydata.groupby(["Channel"],sort=True)["Total"].sum()).reset_index()
a=sns.barplot(x=channelaggregated["Channel"], y=channelaggregated['Total'],data=channelaggregated)
a.set_title("Spending Barplot Channel wise",fontsize=15)
plt.show()

# %%
channelaggregated.head()
# Out:
#   Channel    Total
# 0   Hotel  7999569
# 1  Retail  6619931

# %% [markdown]
# From the above barplot ,it is seen that the Hotel channel is spending the highest while the Retail channel is spending the least .

# %%
plt.figure(figsize=(10,8))
aggregated=pd.DataFrame(mydata.groupby(["Region","Channel"],sort=True)["Total"].sum()).reset_index()
a=sns.barplot(x=aggregated["Region"], y=aggregated['Total'],hue=aggregated["Channel"],data=aggregated)
a.set_title("Spending Barplot for channel wise ",fontsize=15)
plt.show()

# %% [markdown]
# Comparable bar plot with respect to regions and channel:
# We have ploted a comparable bar plot with Hotel assigned as color blue and retail assigned an orange color .
# We are doing the group by of data with channel and retail variables .

# %% [markdown]
# Inference :
# From the above barplot ,it is seen that the other region shows the highest spendings ,hotel channel has more spending then the retail channels .Same pattern can be seen for Lisbon .However,in Oporto region ,retail channel has more spending than hotel channel.

# %% [markdown]
# Drop the total variable

# %%
mydata.drop('Total',axis=1,inplace=True)

# %% [markdown]
# Reconfirm the total column has been dropped or not

# %%
mydata.head()
# Out:
#   Channel Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# 0  Retail  Other  12669  9656     7561     214              2674          1338
# 1  Retail  Other   7057  9810     9568    1762              3293          1776
# 2  Retail  Other   6353  8808     7684    2405              3516          7844
# 3   Hotel  Other  13265  1196     4221    6404               507          1788
# 4  Retail  Other  22615  5410     7198    3915              1777          5185

# %% [markdown]
# Lets check whether all the 6 varieties of items are showing similar behaviour across Region and Channel.

# %% [markdown]
# We will subset the data set with respect to Region and channel.

# %% [markdown]
# Channel wise data subset

# %%
Retail=mydata[mydata['Channel']=="Retail"]
Hotel=mydata[mydata['Channel']=="Hotel"]

# %% [markdown]
# To check the behaviour of all 6 varieties across the Retail we will do descriptive analytics.

# %%
Retail.describe()
# Out:
#               Fresh          Milk  ...  Detergents_Paper  Delicatessen
# count    142.000000    142.000000  ...        142.000000    142.000000
# mean    8904.323944  10716.500000  ...       7269.507042   1753.436620
# std     8987.714750   9679.631351  ...       6291.089697   1953.797047
# min       18.000000    928.000000  ...        332.000000      3.000000
# 25%     2347.750000   5938.000000  ...       3683.500000    566.750000
# 50%     5993.500000   7812.000000  ...       5614.500000   1350.000000
# 75%    12229.750000  12162.750000  ...       8662.500000   2156.000000
# max    44466.000000  73498.000000  ...      40827.000000  16523.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# Total counts of spending done by retail is 142.
# From the varying standard deviation ranging from 1953 to 8987 with higher range ,we found that all variables dont show similar behaviour .
#  The Minimum amount spent on grocery is the highest and Delicatessen is lowest.

# %%
Hotel.describe()
# Out:
#                Fresh          Milk  ...  Detergents_Paper  Delicatessen
# count     298.000000    298.000000  ...        298.000000    298.000000
# mean    13475.560403   3451.724832  ...        790.560403   1415.956376
# std     13831.687502   4352.165571  ...       1104.093673   3147.426922
# min         3.000000     55.000000  ...          3.000000      3.000000
# 25%      4070.250000   1164.500000  ...        183.250000    379.000000
# 50%      9581.500000   2157.000000  ...        385.500000    821.000000
# 75%     18274.750000   4029.500000  ...        899.500000   1548.000000
# max    112151.000000  43950.000000  ...       6907.000000  47943.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# Total counts of spending done by Hotel is 298. From the varying standard deviation ranging from 3147 to 13831 with higher range ,we found that all variables dont show similar behaviour . The Minimum amount spent on Milk is the highest.There are other 4 variables ,on which Hotel has spend same amount of minimum amount of 3.

# %% [markdown]
# Region wise data subset

# %%
Lisbon=mydata[mydata["Region"]=="Lisbon"]
Oporto=mydata[mydata["Region"]=="Oporto"]
Other=mydata[mydata["Region"]=="Other"]

# %%
Lisbon.describe()
# Out:
#               Fresh          Milk  ...  Detergents_Paper  Delicatessen
# count     77.000000     77.000000  ...         77.000000     77.000000
# mean   11101.727273   5486.415584  ...       2651.116883   1354.896104
# std    11557.438575   5704.856079  ...       4208.462708   1345.423340
# min       18.000000    258.000000  ...          5.000000      7.000000
# 25%     2806.000000   1372.000000  ...        284.000000    548.000000
# 50%     7363.000000   3748.000000  ...        737.000000    806.000000
# 75%    15218.000000   7503.000000  ...       3593.000000   1775.000000
# max    56083.000000  28326.000000  ...      19410.000000   6854.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# Total counts of spending done by Lisbon is 77. From the varying standard deviation ranging from 1345 to 11557 with higher range ,we found that all variables dont show similar behaviour . The Minimum amount spent on Grocery is the highest and Detergent Paper is the least.

# %%
Oporto.describe()
# Out:
#               Fresh          Milk  ...  Detergents_Paper  Delicatessen
# count     47.000000     47.000000  ...         47.000000     47.000000
# mean    9887.680851   5088.170213  ...       3687.468085   1159.702128
# std     8387.899211   5826.343145  ...       6514.717668   1050.739841
# min        3.000000    333.000000  ...         15.000000     51.000000
# 25%     2751.500000   1430.500000  ...        282.500000    540.500000
# 50%     8090.000000   2374.000000  ...        811.000000    898.000000
# 75%    14925.500000   5772.500000  ...       4324.500000   1538.500000
# max    32717.000000  25071.000000  ...      38102.000000   5609.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# Total counts of spending done by Oporto is 47. From the varying standard deviation ranging from 1050 to 8387 with higher range ,we found that all variables dont show similar behaviour . The Minimum amount spent on Grocery is the highest and Fresh is the least.

# %%
Other.describe()
# Out:
#                Fresh          Milk  ...  Detergents_Paper  Delicatessen
# count     316.000000    316.000000  ...        316.000000    316.000000
# mean    12533.471519   5977.085443  ...       2817.753165   1620.601266
# std     13389.213115   7935.463443  ...       4593.051613   3232.581660
# min         3.000000     55.000000  ...          3.000000      3.000000
# 25%      3350.750000   1634.000000  ...        251.250000    402.000000
# 50%      8752.500000   3684.500000  ...        856.000000    994.000000
# 75%     17406.500000   7198.750000  ...       3875.750000   1832.750000
# max    112151.000000  73498.000000  ...      40827.000000  47943.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# Total counts of spending done by Other is 316. From the varying standard deviation ranging from 3232 to 13389 with higher range ,we found that all variables dont show similar behaviour . The Minimum amount spent on Milk is the highest.The other 4 variables on which others has spend the minimum amount of 3.

# %% [markdown]
# Descriptive measure of variablility describe the variability or spread in data set .The descriptive measures of variability are range ,IQR,Variance,standard deviation, and coefficient of variance.Here we will use coefficient of variance.

# %% [markdown]
# Coefficient of variance is statistical measure of dispersion of data points in a series around the mean .
# In simple words ,its a ratio of standarad deviation to the mean.
# We are using CV here as this is the most usefull statistical measure to compare the variability from one series to another ,even their means are different from one another.
# It is best suited to our data set where the means are different.

# %%
from scipy.stats import variation

# %%
mydata.columns
# Out:
# Index(['Channel', 'Region', 'Fresh', 'Milk', 'Grocery', 'Frozen',
#        'Detergents_Paper', 'Delicatessen'],
#       dtype='object')

# %%
cols=['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicatessen']

# %%
for i in cols:
  print('The Coefficient of variation for {} is {}'.format(i,round(variation(mydata[i]),3)))
# Out:
# The Coefficient of variation for Fresh is 1.053
# The Coefficient of variation for Milk is 1.272
# The Coefficient of variation for Grocery is 1.194
# The Coefficient of variation for Frozen is 1.579
# The Coefficient of variation for Detergents_Paper is 1.653
# The Coefficient of variation for Delicatessen is 1.847

# %% [markdown]
# All the numerical variable are stored in list named as cols .
# taking i as iterating variable in this list of cols we are find the coefficient of variation value for each variable in data set.
# two curly brackets are used in one each varible will comes iteratively ad second braces will give us the CV value for that variable.

# %% [markdown]
# Inference :
# From the above ressults ,we found that Delicatessen shows the most inconsistent behaviour(High CV values=1.847) and Fresh shows the least inconsistent behaviour (lowest CV values=1.053)

# %% [markdown]
# Outlier Check in data:
# In statsistics ,an outlier is an point that is distant from the other observations in data .
# Boxplot is visual method used to detect the outliers in data .

# %%
mydata.columns
# Out:
# Index(['Channel', 'Region', 'Fresh', 'Milk', 'Grocery', 'Frozen',
#        'Detergents_Paper', 'Delicatessen'],
#       dtype='object')

# %%
fig,axes=plt.subplots(nrows=2,ncols=3)
fig.set_size_inches(18,10)
a=sns.boxplot(data=mydata,x='Fresh',orient="v",ax=axes[0][0])
a.set_title("Fresh Boxplot",fontsize=15)
b=sns.boxplot(data=mydata,x='Milk',orient="v",ax=axes[0][1])
b.set_title("Milk Boxplot",fontsize=15)
c=sns.boxplot(data=mydata,x='Grocery',orient="v",ax=axes[0][2])
c.set_title("Grocery Boxplot",fontsize=15)
d=sns.boxplot(data=mydata,x='Frozen',orient="v",ax=axes[1][0])
d.set_title("Frozen Boxplot",fontsize=15)
e=sns.boxplot(data=mydata,x='Detergents_Paper',orient="v",ax=axes[1][1])
e.set_title("Detergents_Paper Boxplot",fontsize=15)
f=sns.boxplot(data=mydata,x='Delicatessen',orient="v",ax=axes[1][2])
f.set_title("Delicatessen Boxplot",fontsize=15)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# ...

# %% [markdown]
# From the boxplots,we found that all the variables contains outliers.

# %% [markdown]
# Conclusions:
# Out of all the regions ,Other regions  is spendinfg the highest and Oporto is spending the least .
# Hotel is spending more than Retail.
# Out of all the 6 varieties the highest spending was done on Fresh followed by Grocery ,Milk Frozen,Detergent_Paper and Delicatessen.
# There are outliers present in the data set.
